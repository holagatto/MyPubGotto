# %% [markdown]
# <a href="https://colab.research.google.com/github/holagatto/MyPubGotto/blob/main/AI_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2, preprocess_input, decode_predictions
from tensorflow.keras.preprocessing import image
import numpy as np

# 1. モデルの読み込み
model = MobileNetV2(weights='imagenet')

# 2. アップロードしたファイル名を指定（ここを実際のファイル名に合わせてください）
img_path = 'IMG_9050.JPG'

# 3. 画像の読み込みと変換
try:
    img = image.load_img(img_path, target_size=(224, 224))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)

    # 4. 予測
    preds = model.predict(x)

    # 5. 結果表示
    plt.imshow(img)
    plt.axis('off')
    plt.show()

    print('--- AIの推論結果 ---')
    for i, (imagenet_id, label, score) in enumerate(decode_predictions(preds, top=3)[0]):
        print(f"{i+1}: {label} ({score*100:.2f}%)")

except Exception as e:
    print(f"エラーが発生しました: {e}")
    print("左側のフォルダアイコンの中に、ファイルが正しくアップロードされているか確認してください。")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# --- AIの推論結果 ---
# 1: tabby (8.52%)
# 2: bull_mastiff (7.81%)
# 3: bloodhound (4.78%)
